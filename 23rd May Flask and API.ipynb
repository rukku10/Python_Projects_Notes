# %% [markdown]
# # API-Application Programming Interface

# %%
We all use mobile applications eg facebook google pay banking application gaming application etc

# %% [markdown]
# ### An application programming interface is an interface between either two homogenous or heterogenous aaplications . When we have to establish a communication we need a procedure called as API

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Jupyter notebook is just a simple web application! i.e html page fancy one
# It never executes your code!Jupyter notebook apart from that Pycharm is just a interface which gives easy to use functionalities but through an api it sends to the python interpreter

# %% [markdown]
# ## API stands for application programming interface. In essence, an API acts as a communication layer, or as the name says, an interface, that allows different systems to talk to each other without having to understand exactly what each other does. APIs will help you out to call the functions which is available in another language and is somewhere. Api also connects frontend to the backend part! In simplier terms it is a term not a technology or any language it is a term used to present the communication between two application

# %% [markdown]
# In simplier terms it is a term not a technology or any language it is a term used to present the communication between two application

# %% [markdown]
# ## How we can create an API and what all Frameworks are availabe?

# %% [markdown]
# ### Flask and Django

# %% [markdown]
# So basically flask will give you functions which will help you create API's where the API will establish a function between two apps

# %% [markdown]
# ### SOAP and REST  Soap is a protocol & Rest is a architecture

# %%
They are called as procedures
SOAP- Simple object access protocol
REST-Representational state transfer
Using these procedures we will be able to call functions of some systems

# %% [markdown]
# # So soap is a protocol
# -HTTP and HTTPs are protocol i.e set of rules and if you hit this url with this url there are certain rules that I have attached and you need to follow that rule to that get that particular function

# %% [markdown]
# # Rest is a architecture
# Here we will be using REST
# REST, or REpresentational State Transfer, is an architectural style for providing standards between computer systems on the web, making it easier for systems to communicate with each other.

# %% [markdown]
# ## Flask is nothing but a Micro web development Framework
# Here micro means in a simpliest possible way we will be able to create an API eatablish communition expose youre functions to the outer world
# Here web is internally flask is using mainly two components 1) werkzeus framework  2) jinja framework it uses internally!
# >Werkzeus is using Web server Gateway Interface- It will be responsible for calling functions or request another program to get executed through another system!
# >>Jinja is used to create web templates!
# >>>So internally flask is using 2 things to call template and to call somethingelse

# %% [markdown]
# So when we use google and type deep learning and then we find out that google is sending our searched data to a server
# becuase whatever page it is able to populate or show is available in some system becuase of that we are able to see the urls of different types on one page
# So some database is storing this information and thats how we are getting the data right?
# flow is :
# Google is sending the our serached data to some server and the server is able to find out the data based on our request matches
# So we are sending request based on it we are getting a response
# We are getting numerous amiunt if responses in some seconds

# %% [markdown]
# Like discussed above we discussed we are sending some data where exactly are we sending the data??
# It is being send in the url that we searched. so it has appended deep learning so our request is being appended in the url and is being sent to the server and the data is being fetched from there and in return we get the urls
# i.e every time we request a data it is being appended in the url where it is in the form of query
# where q=deep+learning&rlz=1C1FHFK_enIN989IN989&oq=deep+learning&aqs=chrome..
# So here server is staying at a remote location

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So now while searching in the google for logging in gmail.com when we enter our mail id we are definetely sending some data and while entering password the data is not added in the url.
#
# Also data is encryted but even the encrypted data is not added in the url both in the user id and password none of them is seen in the url. Though the nature of the data is differen tin the both the places we are sending the data from my local system. So client is trying to hit the server! sever is nothing but some other system
#
# So here in this scenario when we are sending the data to the server we cannot see the data in the url in any form neither encryted form or normal like the previous example so in logical senses we can say that
#
# Data is sent to the server where API has different different protocols i.e set of rules for every type of data.
#
# There is something called as HTTP and HTTPS methods- GET POST PUT DELETE

# %% [markdown]
# Both GET and POST Http method or function are used for sending the data both send the data but in a totally different way
# "Hypertext Transfer Protocol"- Full form of Http
# "Hypertext Transfer Protocol Secure" -Full form of Https
#
# GET is used for google query
# In GET we will be able to see our data appended in the url as a query that kind of a request that is possible a GET method!!So my system is sending a request where the request is getting appended along with the url and then hitting the server for that ip address at the baclk end that hold the response data that we want
# So our system is called the CLIENT system who ever is executing the backend logic is called a SERVER
#
# POST is used for gmail login authentication
# PUT is nothing but an update operation
# DELETE is nothing but deleting some sort of data

# %% [markdown]
# What is a REST API example?
# For example, a REST API would use a GET request to retrieve a record, a POST request to create one, a PUT request to update a record, and a DELETE request to delete one. All HTTP methods can be used in API calls. A well-designed REST API is similar to a website running in a web browser with built-in HTTP functionality.

# %%
What is flask?
Flask is nothing but a webframework and using that we will be able to create a web API.
So using that we will be able to get URLS and these urls will be independent

# %%
We have a local url that is 
http://127.0.0.1:5000
