# %% [markdown]
# # 19.3.2 pyMongo
# Practice this file in Lecture notes these are sirs notes

# %% [markdown]
# # MongoDB installations will be done in two modes
# >1) Cluster mode i.e cloud mode Called MONGODB ATLAS
# or
# >>2) Local system i.e Called MONGODB COMPASS

# %% [markdown]
# # STEP 1 Connectivity established

# %% [markdown]
# ### Here we will install a MongoDb driver for local system

# %%
# !python -m pip install pymongo

# %% [markdown]
# ### Here we will install a MongoDb driver for cloud user!

# %%
# !pip install pymongo[srv]

# %% [markdown]
# ### Restart the system after downloading this

# %% [markdown]
# ## How to get the link!
# >>For local system we need to go to the connection create new connection and then i need to copy the link!
# >>>For Cloud system find connect button click and then youll find the url there

# %% [markdown]
# ### This is for local system

# %%
import pymongo
client = pymongo.MongoClient("mongodb://localhost:27017/")
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# ### This is for cloud

# %% [markdown]
# ### This is copied from the altas mongo application and in place of password write test as my password and user name both are test view below

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://test:test@cluster0.xcisb7v.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %% [markdown]
# #### Connectivity established!

# %% [markdown]
# # STEP 2: Create a DB

# %% [markdown]
# ### Creating a database using a local system variable! i.e client

# %%
db_1=client["rukaiya"]

# %% [markdown]
# ### It is created the database but is is not visible!

# %% [markdown]
# Inspite of creating a database in the local MongoDB it wont create database as you wont find it in the local system!

# %% [markdown]
# #### So now checking the lists of databases present in the mongodb local system

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %% [markdown]
# # Step 3 Inside DB create Collection

# %% [markdown]
# Now lets insert data in the database,But in MongoDb we can insert data in the form of collection.
# So in python we consider dictionary to be a collection of data.
# dictionary the data is in key and value pair
# So in MongoDB we need to create a key value pair kind off a structure or call is a JSON structure
# JSON stands for JAVA SCRIPT OBJECT NOTATION!

# %% [markdown]
# So in the database what type of collection is it that i am able to give?

# %%
db_1
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'rukaiya')

# %% [markdown]
# #### So now inside rukaiya my database i am trying to create a collection!

# %%
#collection name is test
collection=db_1["test"]
collection
#Yes my collection just got created inside my database rukaiya and test is the name of the collection where collection
#is just the variable and db_1 is an instance of the collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'rukaiya'), 'test')

# %% [markdown]
# So even after creating a collection and a database we still cannot see all of this in MONGODB local system becuase we havent inserted data inside it yet!
# Only after insertion of the data shall it show

# %% [markdown]
# # Step 4: Insert records

# %%
record ={'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning and Computer vision'}
collection.insert_one(record)

# %% [markdown]
# If i make changes into this record this record is stored somewhere!

# %%
record ={'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning and Computer vision',
        'name':["ruksie",1234,"merchant"]}
collection.insert_one(record)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In place of sql database we cannot create a new column instead we will have to recreate the entire schema i.e the table but in Nosql we can do that easily look at the above example!

# %%
So here on ADHOC basis we can change the structure of the particular collection based databases

# %% [markdown]
# So there are various options in MongoDB itself where we can clone the data ![image.png](attachment:image.png)

# %% [markdown]
# ## Note:
#     AFter adding the data we need to keep refreshing it

# %% [markdown]
# #### Cloning
# a hard drive means to make a duplicate copy of the original source data. This duplicate copy can be either bit for bit which will duplicate EVERYTHING on the disk. Another option is to clone individual partitions, this can be useful if you only want to copy specific data such as an OS or data partition.

# %%
record ={'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning and Computer vision',
        "record_dict" : {"name":'rukku','email_id':'rukaiyamerchant10@icloud.com','phon_number':78564251245}}
collection.insert_one(record)

# %%
record ={'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning and Computer vision',
        'name':["ruksie",1234,"merchant"],
        "record_dict" : {"name":'rukku','email_id':'rukaiyamerchant10@icloud.com','phon_number':78564251245}}
collection.insert_one(record)

# %% [markdown]
# # From start to end basic steps!

# %% [markdown]
# #### Local system

# %%
import pymongo
client = pymongo.MongoClient("mongodb://localhost:27017/")
#client
db_1=client["rukaiya"]
#db_1
collection=db_1["test"]
#collection
record ={'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning and Computer vision',
        'name':["ruksie",1234,"merchant"],
        "record_dict" : {"name":'rukku','email_id':'rukaiyamerchant10@icloud.com','phon_number':78564251245}}
collection.insert_one(record)

# %% [markdown]
# #### Cloud system!

# %%
import pymongo
client_cloud = pymongo.MongoClient("mongodb+srv://test:test@cluster0.xcisb7v.mongodb.net/?retryWrites=true&w=majority")
#client
db_1=client_cloud["rukaiya"]
#db_1
collection=db_1["test"]
#collection
record ={'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning and Computer vision',
        'name':["ruksie",1234,"merchant"],
        "record_dict" : {"name":'rukku','email_id':'rukaiyamerchant10@icloud.com','phon_number':78564251245}}
collection.insert_one(record)

# %% [markdown]
# Select this option!!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then you'll be able to see your data there!

# %% [markdown]
# If we run it multiple times from here we can see multiple results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Collection: It is a group of heterogenous data

# %% [markdown]
# # Table: It is an entity that has a structured format

# %% [markdown]
# #### So collection in mongo db is quite similar to the table in sql database

# %% [markdown]
# # Insertion of multiple record

# %%
list_of_records = [{"name":"Rukaiya",
                   "Hobby" : "Exploring and sitting idle",
                   "Mindset" : "Fit but needs improvement"},
                   
                  {"name" : "Abbas",
                  "Hobby": "Mobile games and F1 along with other sports",
                  "Mindset" : "Super Fit and strong"},
                   
                   {"name":"Sunaina",
                   "Hobby" : "Whatever my heart follows",
                   "Mindset" : "Fit and Strong opinionated",
                    "test" : "Python",
                    "list" : [{"name":"Popoye","age":52,"animal":"Bull Dog","place":"Walt Disney"}]
                    }
                   ]

inst= collection.insert_many(list_of_records)
#So if we want all the ids of the different records we can create an instance of the collection i.e inst variable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here we have unique ids for every record!

# %% [markdown]
# ## Lets print the unique ids of the records we have inserted!

# %%
inserted_IDS = inst.inserted_ids
for Ids , unique_ids in enumerate(inserted_IDS):
    print(f"{Ids}.{unique_ids}")
# Out:
# 0.63f91b598fca6c1b2a054a2a
# 1.63f91b598fca6c1b2a054a2b
# 2.63f91b598fca6c1b2a054a2c

# %%
inserted_IDS = inst.inserted_ids
for unique_ids in enumerate(inserted_IDS):
    print(f"{unique_ids}")
# Out:
# (0, ObjectId('63f91b598fca6c1b2a054a2a'))
# (1, ObjectId('63f91b598fca6c1b2a054a2b'))
# (2, ObjectId('63f91b598fca6c1b2a054a2c'))

# %%
inserted_IDS = inst.inserted_ids
for i in inserted_IDS:
    print(f"{i}")
# Out:
# (2, ObjectId('63f91b598fca6c1b2a054a2c'))
# (2, ObjectId('63f91b598fca6c1b2a054a2c'))
# (2, ObjectId('63f91b598fca6c1b2a054a2c'))

# %%
db_1=client_cloud["rukaiya"]
#db_1
collection=db_1["test"]
#collection
record ={'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning and Computer vision',
        'name':["ruksie",1234,"merchant"],
        "record_dict" : {"name":'rukku','email_id':'rukaiyamerchant10@icloud.com','phon_number':78564251245}}
collection.insert_one(record)

# %% [markdown]
# The above unique Id given by default can be overwritten!!

# %% [markdown]
# ### Why do I get an error when bulk inserting?
#
# If you're bulk inserting and have specified an index that doesn't exist in your data, you will get this error. For example, I had accidentally specified name as a unique index, and the data I was inserting had no keys called name.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ALreday inserted id =1 & id =2
So couldnot keep executy the same hence got error!

# %%
Collection_name = "A to Z Trading Company"
collection = db_1[Collection_name]
record_list =[{'_id' : '1',
         'companyName': 'A to Z trading Company',
        'product': 'Affordable AI',
        'courseoffered':'Computer vision',
        'name':["ruksie",1234,"merchant"]},
        
         {'_id' : '2',
        'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning',
        'name':["sheetal",1234,"kaamble"]}
        
        ]
collection.insert_many(record_list)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# Cell In[55], line 16
#       2 collection = db_1[Collection_name]
#       3 record_list =[{'_id' : '1',
#       4          'companyName': 'A to Z trading Company',
#       5         'product': 'Affordable AI',
#    (...)
#      14
#      15         ]
# ---> 16 collection.insert_many(record_list)
#
# File ~\anaconda3\lib\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:714, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     712 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
# ...

# %% [markdown]
# SOLVED the error!!!
# look at the id number now!
# If it has repeated ids, it wont take the same again!! and will definetly throw an error!
# So now changed id and got the result!!

# %%
Collection_name = "A to Z Trading Company"
collection = db_1[Collection_name]
record_list =[{'_id' : '20',
         'companyName': 'A to Z trading Company',
        'product': 'Affordable AI',
        'courseoffered':'Computer vision',
        'name':["ruksie",1234,"merchant"]},
        
         {'_id' : '21',
        'companyName': 'Ineuron',
        'product': 'Affordable AI',
        'courseoffered':'Deep learning',
        'name':["sheetal",1234,"kaamble"]}
        
        ]
collection.insert_many(record_list)

# %% [markdown]
# ### But the database is rukaiya only!

# %%
Collection_name = "A to Z Trading Company"
collection = db_1[Collection_name]
list_of_records_user_defined_id = [
    {"_id": "6",
    "companyName": "iNeuron",
    "Faculty": "Sudhanshu Kumar"},
    {"_id": "8",
    "companyName": "iNeuron",
    "Faculty": "Virat Sagar"},
]
collection.insert_many(list_of_records_user_defined_id )

# %% [markdown]
# ## Find a record!

# %%
collection.find_one()
# Out:
# {'_id': '1',
#  'companyName': 'A to Z trading Company',
#  'product': 'Affordable AI',
#  'courseoffered': 'Computer vision',
#  'name': ['ruksie', 1234, 'merchant'],
#  'record_dict': {'name': 'rukku',
#   'email_id': 'rukaiyamerchant10@icloud.com',
#   'phon_number': 78564251245}}

# %% [markdown]
# ## Here i switched the collection to test from A to Z trading company in the same database as rukaiya

# %%
Collection_name = "test"
collection = db_1[Collection_name]
collection.find_one()
# Out:
# {'_id': ObjectId('63f8d6868fca6c1b2a054a24'),
#  'companyName': 'Ineuron',
#  'product': 'Affordable AI',
#  'courseoffered': 'Deep learning and Computer vision',
#  'name': ['ruksie', 1234, 'merchant'],
#  'record_dict': {'name': 'rukku',
#   'email_id': 'rukaiyamerchant10@icloud.com',
#   'phon_number': 78564251245}}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Find multiple record

# %%
collection.find()

# %% [markdown]
# #### So we will get all the records once we iterate through them

# %%
instance_collection = collection.find()

# %%
for indx,record in enumerate(instance_collection):
    print(f"{indx}.{record}")
#Just incase if you try to run and it doesnt please re-run the above cell and then run this cell again!
# Out:
# 0.{'_id': ObjectId('63f8d6868fca6c1b2a054a24'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# 1.{'_id': ObjectId('63f913a28fca6c1b2a054a26'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# 2.{'_id': ObjectId('63f919b78fca6c1b2a054a27'), 'name': 'Rukaiya', 'Hobby': 'Exploring and sitting idle', 'Mindset': 'Fit but needs improvement'}
# 3.{'_id': ObjectId('63f919b78fca6c1b2a054a28'), 'name': 'Abbas', 'Hobby': 'Mobile games and F1 along with other sports', 'Mindset': 'Super Fit and strong'}
# ...

# %%
Collection_name = "A to Z Trading Company"
collection = db_1[Collection_name]

# %% [markdown]
# ## So now switched my collection to the above!

# %% [markdown]
# Now if you need to find the record of the person on id 1 how will you do it?

# %%
query = {"_id":"1"} #Here we need to create simple key value pair
result =collection.find(query) #This will find and return the location so we need to parse through this in the result!
for i in result:
    print(i)
# Out:
# {'_id': '1', 'companyName': 'A to Z trading Company', 'product': 'Affordable AI', 'courseoffered': 'Computer vision', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}

# %% [markdown]
# ### Another method is

# %%
for i in collection.find({"_id":"20"}):
    print(i)
# Out:
# {'_id': '20', 'companyName': 'A to Z trading Company', 'product': 'Affordable AI', 'courseoffered': 'Computer vision', 'name': ['ruksie', 1234, 'merchant']}

# %%
atoz = collection.find()
for i in atoz:
    print(i)
# Out:
# {'_id': '1', 'companyName': 'A to Z trading Company', 'product': 'Affordable AI', 'courseoffered': 'Computer vision', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': ObjectId('63f925798fca6c1b2a054a2d'), '_idcompanyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning', 'name': ['sheetal', 1234, 'kaamble'], 'record_dict': {'name': 'sheetal', 'email_id': 'sheetalkaam18@icloud.com', 'phon_number': 86524251245}}
# {'_id': '6', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar'}
# {'_id': '8', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar'}
# {'_id': '20', 'companyName': 'A to Z trading Company', 'product': 'Affordable AI', 'courseoffered': 'Computer vision', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': '21', 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning', 'name': ['sheetal', 1234, 'kaamble']}

# %% [markdown]
# ### If no record available it will give a blank

# %%
for i in collection.find({"_id":"20000"}):
    print(i)
#Since no such record!

# %%
for i in collection.find({"_idpp":"20000"}):
    print(i)
#If mistake in key again no record will be displayed!

# %% [markdown]
# ## Find Ids Greater or equal to 2

# %% [markdown]
# So in MongoDB we will be able to find a particular notation for all the operations that is > ,< ,= etc!
# And most importantly everything works in a key value pair!

# %%
for i in collection.find({"_id":{"$gt":"1"}}):
    print(i)
# Out:
# {'_id': '20', 'companyName': 'A to Z trading Company', 'product': 'Affordable AI', 'courseoffered': 'Computer vision', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': '21', 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning', 'name': ['sheetal', 1234, 'kaamble']}
# {'_id': '6', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar'}
# {'_id': '8', 'companyName': 'iNeuron', 'Faculty': 'Virat Sagar'}

# %%
For greater than equal too it is "$gte"

# %%
for i in collection.find({"_id":{"$lt":"8"}}):
    print(i)
# Out:
# {'_id': '1', 'companyName': 'A to Z trading Company', 'product': 'Affordable AI', 'courseoffered': 'Computer vision', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': '20', 'companyName': 'A to Z trading Company', 'product': 'Affordable AI', 'courseoffered': 'Computer vision', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': '21', 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning', 'name': ['sheetal', 1234, 'kaamble']}
# {'_id': '6', 'companyName': 'iNeuron', 'Faculty': 'Sudhanshu Kumar'}

# %%
collection.find()

# %% [markdown]
# # Delete query

# %%
query = {'Faculty': 'Sudhanshu Kumar'}
query1 ={'_id' : {'$gte': '1'}}
collection.delete_one(query)
collection.delete_many(query1)

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': ObjectId('63f925798fca6c1b2a054a2d'), '_idcompanyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning', 'name': ['sheetal', 1234, 'kaamble'], 'record_dict': {'name': 'sheetal', 'email_id': 'sheetalkaam18@icloud.com', 'phon_number': 86524251245}}

# %% [markdown]
# # Update query

# %%
But for that we need to add new ids to the collection a to z

# %%
list_of_records = [{"name":"Rukaiya",
                    "_id":10,
                   "Hobby" : "Exploring and sitting idle",
                   "Mindset" : "Fit but needs improvement"},
                   
                  {"name" : "Abbas",
                    "_id":11,
                  "Hobby": "Mobile games and F1 along with other sports",
                  "Mindset" : "Super Fit and strong"},
                   
                   {"name":"Sunaina",
                     "_id":12,
                   "Hobby" : "Whatever my heart follows",
                   "Mindset" : "Fit and Strong opinionated",
                    "test" : "Python",
                    "list" : [{"name":"Popoye","age":52,"animal":"Bull Dog","place":"Walt Disney"}]
                    }
                   ]
instance2 = collection.insert_many(list_of_records)

# %%
instance2

# %%
for i in instance2.inserted_ids:
    print(i)
# Out:
# 10
# 11
# 12

# %%
collection.find()

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': ObjectId('63f925798fca6c1b2a054a2d'), '_idcompanyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning', 'name': ['sheetal', 1234, 'kaamble'], 'record_dict': {'name': 'sheetal', 'email_id': 'sheetalkaam18@icloud.com', 'phon_number': 86524251245}}
# {'_id': 10, 'name': 'Rukaiya', 'Hobby': 'Exploring and sitting idle', 'Mindset': 'Fit but needs improvement'}
# {'_id': 11, 'name': 'Abbas', 'Hobby': 'Mobile games and F1 along with other sports', 'Mindset': 'Super Fit and strong'}
# {'_id': 12, 'name': 'Sunaina', 'Hobby': 'Whatever my heart follows', 'Mindset': 'Fit and Strong opinionated', 'test': 'Python', 'list': [{'name': 'Popoye', 'age': 52, 'animal': 'Bull Dog', 'place': 'Walt Disney'}]}

# %% [markdown]
# ## Updating using the above info inserted in the collection

# %%
present_data ={'name': 'Rukaiya'}
new_data ={"$set":{'name': 'Mrs. Plumber'}}
collection.update_one(present_data,new_data)

# %%
for index , record in enumerate(collection.find()):
    print(f"{index}.{record}\n")
# Out:
# 0.{'_id': ObjectId('63f925798fca6c1b2a054a2d'), '_idcompanyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning', 'name': ['sheetal', 1234, 'kaamble'], 'record_dict': {'name': 'sheetal', 'email_id': 'sheetalkaam18@icloud.com', 'phon_number': 86524251245}}
#
# 1.{'_id': 10, 'name': 'Mrs. Plumber', 'Hobby': 'Exploring and sitting idle', 'Mindset': 'Fit but needs improvement'}
#
# 2.{'_id': 11, 'name': 'Abbas', 'Hobby': 'Mobile games and F1 along with other sports', 'Mindset': 'Super Fit and strong'}
#
# 3.{'_id': 12, 'name': 'Sunaina', 'Hobby': 'Whatever my heart follows', 'Mindset': 'Fit and Strong opinionated', 'test': 'Python', 'list': [{'name': 'Popoye', 'age': 52, 'animal': 'Bull Dog', 'place': 'Walt Disney'}]}

# %% [markdown]
# # STEP 8: Drop the entire collection

# %%
faculties.drop()

# %%
# Lets verify if the collection exists or not after dropping it
COLLECTION_NAME = "iNeuron_Faculties"
DB_NAME = "iNeuron"
_ = checkExistence_COL(COLLECTION_NAME=COLLECTION_NAME, DB_NAME=DB_NAME, db=dataBase)

# %% [markdown]
# # STEP 9: Set limit to view N records

# %%
N_records = 3

N_record = products.find().limit(N_records)

for idx, record in enumerate(N_record):
    print(f"{record}\n")

# %% [markdown]
# # PRACTICE

# %% [markdown]
# For local driver we install this

# %%
# !python -m pip install pymongo

# %% [markdown]
# #### Importing packages and creating client connection

# %%
import pymongo
client = pymongo.MongoClient("mongodb://localhost:27017")
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# #### Creating my own database! in the local system

# %%
database =client["mydatabase1"]
database #this is the variable name and database name is mydatabase1
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase1')

# %% [markdown]
# Inspite of creating a databse we cannot see it becuase we havent inserted anything in the dtaabse as of yet

# %% [markdown]
# #### Using the client i.e the connection we are checking how many databases are created before

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'mydatabase1', 'rukaiya']

# %% [markdown]
# #### So now we will create a collection inside the created database

# %%
database
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase1')

# %% [markdown]
# #### So now creating a collection and its name

# %% [markdown]
# ## My collection name is prac1

# %%
collection=database["prac1"]
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase1'), 'prac1')

# %% [markdown]
# #### Now inserting data in the form of dictionary since python has a key value pair collection in the form of a dictionary

# %% [markdown]
# ### The error is because i ran the code twice

# %%
record =[{'_id':103,
          'name':'Ruksoilik',
          'dob':1998,
          "age":26
         }
         ,
         {'_id':104,
          'name':'Abbasilkjn',
          'dob':1993,
          "age":31
         }
        ]
inst = collection.insert_many(record)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# Cell In[8], line 13
#       1 record =[{'_id':103,
#       2           'name':'Ruksoilik',
#       3           'dob':1998,
#    (...)
#      11          }
#      12         ]
# ---> 13 inst = collection.insert_many(record)
#
# File ~\anaconda3\lib\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:714, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     712 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     713 blk.ops = [doc for doc in gen()]
# --> 714 blk.execute(write_concern, session=session)
# ...

# %%
record = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program',
    "test" : "ffsdfsffsf",
     "complex" : [{"name" : "sudhanshu","list" : [554,545,454,54,5,4]},{"email_id" :"sudhanshu@dffsf"},{"phone_no":345345345353},[4,54,534,5,45,5,45,4]]

    }]

instance2 = collection.insert_many(record)

# %%
collection.find_one()
# Out:
# {'_id': 101, 'name': 'Ruks', 'dob': 1998, 'age': 24}

# %%
record =[{'_id':101,
          'name':'Ruks',
          'dob':1998,
          "age":24
         }
         ,
         {'_id':102,
          'name':'Abbas',
          'dob':1993,
          "age":29
         }
        ]
collection.insert_many(record)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# Cell In[11], line 13
#       1 record =[{'_id':101,
#       2           'name':'Ruks',
#       3           'dob':1998,
#    (...)
#      11          }
#      12         ]
# ---> 13 collection.insert_many(record)
#
# File ~\anaconda3\lib\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:714, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     712 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     713 blk.ops = [doc for doc in gen()]
# --> 714 blk.execute(write_concern, session=session)
# ...

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'mydatabase1', 'rukaiya']

# %% [markdown]
# #### Now lets check the inserted ids we've inserted

# %%
inserted_IDS = inst.inserted_ids
for i in inserted_IDS:
    print(f"{i}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 inserted_IDS = inst.inserted_ids
#       2 for i in inserted_IDS:
#       3     print(f"{i}")
#
# NameError: name 'inst' is not defined

# %% [markdown]
# ### Find multiple records

# %%
instance=collection.find()

# %%
for i in instance:
    print(i)
# Out:
# {'_id': 101, 'name': 'Ruks', 'dob': 1998, 'age': 24}
# {'_id': 102, 'name': 'Abbas', 'dob': 1993, 'age': 29}
# {'_id': 103, 'name': 'Ruksoilik', 'dob': 1998, 'age': 26}
# {'_id': 104, 'name': 'Abbasilkjn', 'dob': 1993, 'age': 31}
# {'_id': ObjectId('63fbf91e18eb1bb503423be1'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63fbf91e18eb1bb503423be2'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('63fbf91e18eb1bb503423be3'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program', 'test': 'ffsdfsffsf', 'complex': [{'name': 'sudhanshu', 'list': [554, 545, 454, 54, 5, 4]}, {'email_id': 'sudhanshu@dffsf'}, {'phone_no': 345345345353}, [4, 54, 534, 5, 45, 5, 45, 4]]}
# ...

# %% [markdown]
# ### Find a single record

# %%
ins=collection.find_one()

# %%
ins
# Out:
# {'_id': 101, 'name': 'Ruks', 'dob': 1998, 'age': 24}

# %% [markdown]
# ### Find ids greater or lesser than

# %%
for i in collection.find({"_id":{"$gt":"101"}}):
    print(i)

# %%
for i in collection.find():
    print(i)
# Out:
# {'_id': 101, 'name': 'Ruks', 'dob': 1998, 'age': 24}
# {'_id': 102, 'name': 'Abbas', 'dob': 1993, 'age': 29}
# {'_id': 103, 'name': 'Ruksoilik', 'dob': 1998, 'age': 26}
# {'_id': 104, 'name': 'Abbasilkjn', 'dob': 1993, 'age': 31}
# {'_id': ObjectId('63fbf91e18eb1bb503423be1'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63fbf91e18eb1bb503423be2'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('63fbf91e18eb1bb503423be3'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program', 'test': 'ffsdfsffsf', 'complex': [{'name': 'sudhanshu', 'list': [554, 545, 454, 54, 5, 4]}, {'email_id': 'sudhanshu@dffsf'}, {'phone_no': 345345345353}, [4, 54, 534, 5, 45, 5, 45, 4]]}
# ...

# %%
for i in collection.find({"_id":{"$gte":101}}):
    print(i)
# Out:
# {'_id': 101, 'name': 'Ruks', 'dob': 1998, 'age': 24}
# {'_id': 102, 'name': 'Abbas', 'dob': 1993, 'age': 29}
# {'_id': 103, 'name': 'Ruksoilik', 'dob': 1998, 'age': 26}
# {'_id': 104, 'name': 'Abbasilkjn', 'dob': 1993, 'age': 31}

# %%
# Out:
#   Cell In[1], line 1
#     use rukaiya
#         ^
# SyntaxError: invalid syntax

# %%
import pymongo
client = pymongo.MongoClient("mongodb://localhost:27017")
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db_1=client["rukaiya"]

# %%
db_1
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'rukaiya')

# %%
collection = db_1["test"]
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'rukaiya'), 'test')

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'mydatabase1', 'rukaiya']

# %%
instances= collection.find()

# %%
for i in instances:
    print(i)
# Out:
# {'_id': ObjectId('63f8c16d8fca6c1b2a054a1c'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision'}
# {'_id': ObjectId('63f8c3078fca6c1b2a054a1d'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': ObjectId('63f8c7ae8fca6c1b2a054a1e'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision', 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': ObjectId('63f8c7f08fca6c1b2a054a1f'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}

# %%
db_1.test.update_one({'companyName':'Ineuron'},
                     {
                         '$set': {"product":"AI"}
                     })

# %%
instances= collection.find()

# %%
for i in instances:
    print(i)
# Out:
# {'_id': ObjectId('63f8c16d8fca6c1b2a054a1c'), 'companyName': 'Ineuron', 'product': 'AI', 'courseoffered': 'Deep learning and Computer vision'}
# {'_id': ObjectId('63f8c3078fca6c1b2a054a1d'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': ObjectId('63f8c7ae8fca6c1b2a054a1e'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision', 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': ObjectId('63f8c7f08fca6c1b2a054a1f'), 'companyName': 'Ineuron', 'product': 'Affordable AI', 'courseoffered': 'Deep learning and Computer vision', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}

# %%
db_1.test.update_many({'companyName':'Ineuron'},
                     {
                         '$set' : {"companyName":"A to Z", "courseoffered": "Hardware"}
                     })

# %%
instances= collection.find()
for i in instances:
    print(i)
# Out:
# {'_id': ObjectId('63f8c16d8fca6c1b2a054a1c'), 'companyName': 'A to Z', 'product': 'AI', 'courseoffered': 'Hardware'}
# {'_id': ObjectId('63f8c3078fca6c1b2a054a1d'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': ObjectId('63f8c7ae8fca6c1b2a054a1e'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': ObjectId('63f8c7f08fca6c1b2a054a1f'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}

# %%
db_1.test.replace_one({'product':'AI'},
                     {
                         'product':'Sectoral study'
                     })

# %%
db_1.test.replace_one({'product':'Sectoral study'},
                     {
                         'companyName': 'A to Z', 'product': 'AI', 'courseoffered': 'Hardware'
                     })

# %%
instances= collection.find()
for i in instances:
    print(i)
# Out:
# {'_id': ObjectId('63f8c16d8fca6c1b2a054a1c'), 'product': 'Sectoral study'}
# {'_id': ObjectId('63f8c3078fca6c1b2a054a1d'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': ObjectId('63f8c7ae8fca6c1b2a054a1e'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': ObjectId('63f8c7f08fca6c1b2a054a1f'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}

# %%
instances= collection.find()
for i in instances:
    print(i)
# Out:
# {'_id': ObjectId('63f8c16d8fca6c1b2a054a1c'), 'companyName': 'A to Z', 'product': 'AI', 'courseoffered': 'Hardware'}
# {'_id': ObjectId('63f8c3078fca6c1b2a054a1d'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': ObjectId('63f8c7ae8fca6c1b2a054a1e'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': ObjectId('63f8c7f08fca6c1b2a054a1f'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}

# %%
db_1.test.replace_one({'companyName': 'A to Z'},
                     {
                         'product':'Sectoral study'
                     })

# %%
instances= collection.find()
for i in instances:
    print(i)
# Out:
# {'_id': ObjectId('63f8c16d8fca6c1b2a054a1c'), 'product': 'Sectoral study'}
# {'_id': ObjectId('63f8c3078fca6c1b2a054a1d'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': ObjectId('63f8c7ae8fca6c1b2a054a1e'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': ObjectId('63f8c7f08fca6c1b2a054a1f'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}

# %%
db_1.test.replace_one({'product':'Sectoral study'},
                     {
                         'companyName': 'A to Z', 'product': 'AI', 'courseoffered': 'Hardware'
                     })

# %%
instances= collection.find()
for i in instances:
    print(i)
# Out:
# {'_id': ObjectId('63f8c16d8fca6c1b2a054a1c'), 'companyName': 'A to Z', 'product': 'AI', 'courseoffered': 'Hardware'}
# {'_id': ObjectId('63f8c3078fca6c1b2a054a1d'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant']}
# {'_id': ObjectId('63f8c7ae8fca6c1b2a054a1e'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}
# {'_id': ObjectId('63f8c7f08fca6c1b2a054a1f'), 'companyName': 'A to Z', 'product': 'Affordable AI', 'courseoffered': 'Hardware', 'name': ['ruksie', 1234, 'merchant'], 'record_dict': {'name': 'rukku', 'email_id': 'rukaiyamerchant10@icloud.com', 'phon_number': 78564251245}}

# %%
db_2 = client["mydatabase1"]

# %%
collection = db_2["prac1"]

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase1'), 'prac1')

# %%
str1= db_2.prac1.find()

# %%
for i in str1:
    print(i)
# Out:
# {'_id': 101, 'name': 'Ruks', 'dob': 1998, 'age': 24}
# {'_id': 102, 'name': 'Abbas', 'dob': 1993, 'age': 29}
# {'_id': 103, 'name': 'Ruksoilik', 'dob': 1998, 'age': 26}
# {'_id': 104, 'name': 'Abbasilkjn', 'dob': 1993, 'age': 31}
# {'_id': ObjectId('63fbf91e18eb1bb503423be1'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63fbf91e18eb1bb503423be2'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('63fbf91e18eb1bb503423be3'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program', 'test': 'ffsdfsffsf', 'complex': [{'name': 'sudhanshu', 'list': [554, 545, 454, 54, 5, 4]}, {'email_id': 'sudhanshu@dffsf'}, {'phone_no': 345345345353}, [4, 54, 534, 5, 45, 5, 45, 4]]}
# ...

# %% [markdown]
# iterator
# generator
# oops

# %%
# !python -m pip install pymongo

# %%
import pymongo

# %%
import json

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db_3=client["mydatabase3"]

# %%
collection = db_3["sample_collection"]

# %%
with open("data.json") as file:
    file_data = json.load(file)

# %%
collection.insert_one(file_data)

# %% [markdown]
# https://hevodata.com/learn/json-to-mongodb-python/#7
